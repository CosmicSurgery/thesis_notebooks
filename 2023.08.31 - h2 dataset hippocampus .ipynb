# %%
import tarfile
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file =r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.clu.1'

# %%
os.path.abspath('C:\\Users\\miles\\Projects\\datasets')
# Out:
# 'C:\\Users\\miles\\Projects\\datasets'

# %%
def get_data(labels_file, spikes_file):
#     labels_file = open(labels_file)
    labels = labels_file.readlines()
    labels = np.array([k[:-1] for k in labels],dtype='int')[1:]
#     labels = np.array([k[:-1] for k in labels])
    
    spikes = spikes_file.readlines()
    spikes = np.array([k[:-1] for k in spikes],dtype='float')
    return labels, spikes

# %% [markdown]
# # h2 datasets Hippocampus

# %%
(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.clu.1'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.res.1')
)
labels1, spikes1 = get_data(labels_file, spikes_file)

(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.clu.2'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.res.2')
)
labels2, spikes2 = get_data(labels_file, spikes_file)
(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.clu.3'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.res.3')
)
labels3, spikes3 = get_data(labels_file, spikes_file)
(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.clu.4'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec013.527\ec013.527.res.4')
)
labels4, spikes4 = get_data(labels_file, spikes_file)

# %%
fig, ax = plt.subplot_mosaic('A;B;C;D',figsize=(12,16))
ax['A'].scatter(spikes1,labels1)
ax['B'].scatter(spikes2,labels2)
ax['C'].scatter(spikes3,labels3)
ax['D'].scatter(spikes4,labels4)
plt.show()

# %%
(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.clu.1'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.res.1')
)
labels1, spikes1 = get_data(labels_file, spikes_file)

(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.clu.2'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.res.2')
)
labels2, spikes2 = get_data(labels_file, spikes_file)
(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.clu.3'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.res.3')
)
labels3, spikes3 = get_data(labels_file, spikes_file)
(labels_file, spikes_file) = (
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.clu.4'),
    open(r'C:\Users\miles\Projects\datasets\crcns\hc2\ec014.793\ec014.793.res.4')
)
labels4, spikes4 = get_data(labels_file, spikes_file)

# %%
labels1
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
fig, ax = plt.subplot_mosaic('A;B;C;D',figsize=(12,16))
ax['A'].scatter(spikes1,labels1)
ax['B'].scatter(spikes2,labels2)
ax['C'].scatter(spikes3,labels3)
ax['D'].scatter(spikes4,labels4)
plt.show()

# %% [markdown]
# # ac3 datasets Auditory Cortex

# %%
filenames = os.listdir(r'C:\Users\miles\Projects\datasets\crcns\ac3\Data')
filenames
# Out:
# ['site1-rn1.mat',
#  'site10-rn16.mat',
#  'site11-rn1.mat',
#  'site12-rn16.mat',
#  'site13-rn1.mat',
#  'site14-rn16.mat',
#  'site15-rn1.mat',
#  'site16-rn16.mat',
#  'site2-rn16.mat',
#  'site3-rn1.mat',
#  'site4-rn16.mat',
#  'site5-rn1.mat',
#  'site6-rn16.mat',
#  'site7-rn1.mat',
#  'site8-rn16.mat',
#  'site9-rn1.mat']

# %%
k
# Out:
# 'site9-rn1.mat'

# %%
import scipy.io
test = [scipy.io.loadmat(r'C:\Users\miles\Projects\datasets\crcns\ac3\Data\\'+k) for k in filenames]

# %%
df = pd.DataFrame(test[0]['spk'][0])

# %%
df
# Out:
#       chan        model    depth      position   stim  \
# 0    [[3]]        [[0]]  [[800]]   [[50, 250]]  [rn1]
# 1   [[17]]        [[1]]  [[800]]  [[-50, 300]]  [rn1]
# 2    [[5]]        [[1]]  [[800]]   [[50, 300]]  [rn1]
# 3   [[27]]     [[1, 2]]  [[800]]  [[-50, 350]]  [rn1]
# 4   [[27]]        [[3]]  [[800]]  [[-50, 350]]  [rn1]
# 5   [[22]]     [[0, 1]]  [[800]]  [[-50, 400]]  [rn1]
# 6   [[22]]        [[2]]  [[800]]  [[-50, 400]]  [rn1]
# 7   [[22]]        [[3]]  [[800]]  [[-50, 400]]  [rn1]
# 8   [[20]]     [[0, 1]]  [[800]]  [[-50, 450]]  [rn1]
# 9   [[20]]        [[2]]  [[800]]  [[-50, 450]]  [rn1]
# 10  [[18]]        [[0]]  [[800]]    [[0, 450]]  [rn1]
# 11  [[18]]        [[1]]  [[800]]    [[0, 450]]  [rn1]
# 12  [[18]]        [[5]]  [[800]]    [[0, 450]]  [rn1]
# 13  [[14]]        [[3]]  [[800]]   [[50, 450]]  [rn1]
# 14  [[14]]        [[4]]  [[800]]   [[50, 450]]  [rn1]
# 15  [[25]]        [[1]]  [[800]]  [[-50, 500]]  [rn1]
# ...

# %%
fs = 20 # Sampling rate in kHz

# %%
test[0]['spk'][0]['spiketimes'][0].squeeze().shape
# Out:
# (3731,)

# %%
num_units = test[0]['spk'][0]['spiketimes'].shape[0]
spikes = np.array([])
labels = np.array([])
for i in range(num_units):
    spikes = np.hstack((spikes,test[0]['spk'][0]['spiketimes'][i].squeeze()))
    labels = np.hstack((labels,i*np.ones_like(test[0]['spk'][0]['spiketimes'][i].squeeze())))
spikes, labels = spikes[spikes.argsort()], labels[spikes.argsort()] # sorting the arrays by spike time
print(spikes.shape,labels.shape)
# Out:
# (72240,) (72240,)

# %%
plt.figure(figsize=(12,6))
cut = slice(70,100)
plt.scatter(spikes[cut],labels[cut])
plt.xlabel('Time (ms)')
plt.show()

# %%
plt.figure(figsize=(12,6))
cut = slice(0,1000)
plt.scatter(spikes[cut],labels[cut])
plt.xlabel('Time (ms)')
plt.show()
