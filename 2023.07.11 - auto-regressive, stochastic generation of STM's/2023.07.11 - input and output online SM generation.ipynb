# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
input neuron will be a fixed in time spike train
'''
spikes = [111, 256, 467, 689, 731]

plt.figure()
plt.scatter(spikes, np.zeros_like(spikes),marker='|',s=1000)
plt.show()

# %%
T = 1000
t = 0
th = 1
v=0

# %%
pattern =
