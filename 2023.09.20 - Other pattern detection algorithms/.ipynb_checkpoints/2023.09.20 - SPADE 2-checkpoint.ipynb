# %%
import numpy as np
import quantities as pq
import neo
import elephant
import viziphant
np.random.seed(4542)

# %%
def generate_synthetic_data(params):
    '''
    Synthetic Data Generation
    '''
    # Dense K: matrix of binary images of sizeNxDxM
    # Sparse K: set of (delay d, neuron a, and pg b)

    M,N,D,T,nrn_fr,pg_fr,background_noise_fr,seed = params['M'], params['N'], params['D'], params['T'], params['nrn_fr'],params['pg_fr'],params['background_noise_fr'],params['seed']    
    '''
    Synthetic Data Generation
    '''
    # Dense K: matrix of binary images of sizeNxDxM
    # Sparse K: set of (delay d, neuron a, and pg b)
    np.random.seed(seed)

    K_dense = np.random.rand(N,D,M)*1000
    nrn_frs = np.zeros((M))
    for m in range(M):
        nrn_frs[m] = np.random.poisson(nrn_fr)
        K_dense[:,:,m] = (K_dense[:,:,m] < nrn_frs[m]).astype('int')
    K_sparse = np.where(K_dense)
    K_sparse = (K_sparse[0],K_sparse[1],K_sparse[2]+1)


    # dense B: the binary image of the occurrences of the spiking motif as a ( M x T) matrix
    # spare B: set of all times t and pg's b
    B_dense = np.random.rand(M,T)*1000
    pg_frs = np.zeros((M))
    for m in range(M):
        pg_frs[m] = np.random.poisson(pg_fr)
        B_dense[m,:] = (B_dense[m,:] < pg_frs[m]).astype('int')
    B_sparse = np.where(B_dense)
    B_sparse = (B_sparse[0]+1,B_sparse[1])# This way the first motif starts at index 1 instead of index 0

    # now to make the full raster plot keeping the labels in-tact
    # dense A: the layered binary images of all neuron spikes by PG ( N x T x M
    A_dense = np.zeros((N,T+D,M+1))
    A_dense[...,0] = np.random.rand(N,T+D)*1000
    A_dense[...,0] = (A_dense[...,0] < background_noise_fr).astype('int')
    for i in range(len(B_sparse[0])):
        t = B_sparse[1][i]
        b = B_sparse[0][i]
        A_dense[:, t:t+D, b] += K_dense[...,b-1]

    A_sparse = np.where(A_dense)
    A_dense = np.sum(A_dense,axis=2)
    A_dense[A_dense>1] = 1
    
    return A_dense, A_sparse, B_dense, B_sparse, K_dense, K_sparse

# %%
def fix_spade(patterns, win_size):
    spade_patterns = []
    for pattern in patterns:
        spade_patterns.append(np.sort(np.array(pattern['itemset'])) % D , np.sort(np.array(pattern['neurons'])))
    return spade_patterns

# %%
M = 1
N = 20
D = 51
T = 1000
nrn_fr = 10
pg_fr = 5
background_noise_fr = 5
seed=1

params = {
    'M':M,
    'N':N,
    'D':D,
    'T':T,
    'nrn_fr':nrn_fr,
    'pg_fr':pg_fr,
    'background_noise_fr':background_noise_fr,
    'seed':seed
}

# %%
A_dense, A_sparse, B_dense, B_sparse, K_dense, K_sparse = generate_synthetic_data(params)

# %%
len(A_sparse[0])
# Out:
# 162

# %%
import seaborn as sns
import matplotlib.pyplot as plt
palette = np.array(sns.color_palette("tab10"))

# %%
plt.figure()
plt.scatter(K_sparse[1],K_sparse[0])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(A_sparse[1],A_sparse[0],c=palette[A_sparse[2]],alpha=0.7)
# plt.scatter(A_sparse[1],A_sparse[0],c='black',alpha=0.7)
plt.show()

# %% [markdown]
# ### I have to use the annoying spiketrain objects...

# %%
from neo.core import SpikeTrain

# %%
spike_trains = [SpikeTrain(A_sparse[1][A_sparse[0]==n] ,units= pq.ms, t_stop=T+D) for n in range(N)]

# %%
viziphant.rasterplot.rasterplot(spike_trains)
# Out:
# <Axes: xlabel='Time (ms)'>

# %%
import time

# %%
start = time.time()
patterns = elephant.spade.spade(spike_trains, bin_size=pq.ms, winlen=D,
    output_format='patterns')['patterns']
end = time.time()
print(end - start)
# Out:
# Time for data mining: 0.05424380302429199
# 0.06583905220031738

# %%
import pandas as pd

# %%
df = pd.DataFrame(patterns)

# %%
len(patterns)
# Out:
# 30

# %%
patterns[27]
# Out:
# {'itemset': (248, 675, 688, 485, 737, 742, 441, 567, 96, 0),
#  'windows_ids': (219, 333, 400, 580, 803),
#  'neurons': [0, 11, 13, 14, 13, 9, 14, 8, 4, 1],
#  'lags': array([ 6., 12., 23., 25., 26., 28., 33., 44., 45.]) * ms,
#  'times': array([219., 333., 400., 580., 803.]) * ms,
#  'signature': (10, 5),
#  'pvalue': -1}

# %%
patterns[-3]
# Out:
# {'itemset': (248, 675, 688, 485, 737, 742, 441, 567, 96, 0),
#  'windows_ids': (219, 333, 400, 580, 803),
#  'neurons': [0, 11, 13, 14, 13, 9, 14, 8, 4, 1],
#  'lags': array([ 6., 12., 23., 25., 26., 28., 33., 44., 45.]) * ms,
#  'times': array([219., 333., 400., 580., 803.]) * ms,
#  'signature': (10, 5),
#  'pvalue': -1}

# %%
test = patterns[0].copy()

# %%
test['lags']
# Out:
# array([18.]) * ms

# %%
test
# Out:
# {'itemset': (69, 357),
#  'windows_ids': (33, 475),
#  'neurons': [7, 1],
#  'lags': array([18.]) * ms,
#  'times': array([ 33., 475.]) * ms,
#  'signature': (2, 2),
#  'pvalue': -1}

# %%
# test['itemset'] = tuple(K_sparse[1])
test['itemset'] = tuple((0,33,66,100,133,166,200,233))
test['neurons'] = tuple(K_sparse[0])
test['times'] = tuple(B_sparse[1]) * pq.ms
test['lags'] = tuple((33,66,100,133,166,200,233))

# %%
viziphant.patterns.plot_patterns(spike_trains, test)
# Out:
# <Axes: xlabel='Time (ms)', ylabel='Neuron'>

# %%
for i in range(30):
    viziphant.patterns.plot_patterns(spike_trains, patterns[i])

# %%
# old = patterns

# %%
test = enumerate(patterns)
next(test)
# Out:
# (0,
#  {'itemset': (69, 357),
#   'windows_ids': (33, 475),
#   'neurons': [7, 1],
#   'lags': array([18.]) * ms,
#   'times': array([ 33., 475.]) * ms,
#   'signature': (2, 2),
#   'pvalue': -1})

# %%
patterns[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [182], in <cell line: 1>()
# ----> 1 patterns[0]
#
# KeyError: 0

# %%
possible_patterns = [(tuple(np.array(k['itemset'])%(D)), k['neurons']) for k in patterns]

# %%
old = patterns.copy()

# %%
patterns=patterns[27]
patterns
# Out:
# {'itemset': (248, 675, 688, 485, 737, 742, 441, 567, 96, 0),
#  'windows_ids': (219, 333, 400, 580, 803),
#  'neurons': [0, 11, 13, 14, 13, 9, 14, 8, 4, 1],
#  'lags': array([ 6., 12., 23., 25., 26., 28., 33., 44., 45.]) * ms,
#  'times': array([219., 333., 400., 580., 803.]) * ms,
#  'signature': (10, 5),
#  'pvalue': -1}

# %%
if isinstance(patterns, dict):
    patterns = [patterns]
# axes = rasterplot(spiketrains, color='darkgray', s=circle_sizes[0])
# units = spiketrains[0].units
# time_scalar = units.rescale('ms').item()
# patterns_overlap = defaultdict(lambda: defaultdict(list))

# if colors is None:
#     # +1 is necessary
#     cmap = plt.cm.get_cmap("hsv", len(patterns) + 1)
#     colors = np.array([cmap(i) for i in range(len(patterns))])
# elif not isinstance(colors, (list, tuple, np.ndarray)):
#     raise TypeError("'colors' must be a list of colors")
# elif len(colors) != len(patterns):
#     raise ValueError("The length of 'colors' must match the length of "
#                      "the input 'patterns'.")


times_ms = pattern['times'].rescale(pq.ms).magnitude.astype(int)
for neuron in pattern['neurons']:
    for t in times_ms:
        patterns_overlap[neuron][t].append(pattern_id)

times_s = pattern['times'].rescale(units).magnitude
times_ms = (times_s * time_scalar).astype(int)
for neuron in pattern['neurons']:
    mask_overlapped = np.zeros(len(times_ms), dtype=bool)
    for i, t in enumerate(times_ms):
        mask_overlapped[i] = len(patterns_overlap[neuron][t]) > 1
    times_no_overlap = times_s[~mask_overlapped]
#         axes.scatter(times_no_overlap,
#                      np.repeat(neuron, repeats=len(times_no_overlap)),
#                      c=[colors[pattern_id]], s=circle_sizes[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [192], in <cell line: 18>()
#      20     for neuron in pattern['neurons']:
#      21         for t in times_ms:
# ---> 22             patterns_overlap[neuron][t].append(pattern_id)
#      23 for pattern_id, pattern in enumerate(patterns):
#      24     times_s = pattern['times'].rescale(units).magnitude
#
# NameError: name 'patterns_overlap' is not defined

# %%
for d in range(D):
    plt.figure(figsize=(12,6))
    plt.scatter(K_sparse[1],K_sparse[0],s=100)
    plt.scatter(patterns[0],patterns[1],s=100)
    plt.show()

# %%
K_sparse[0]
# Out:
# array([ 0,  1,  4,  8,  9, 11, 13, 13, 14, 14], dtype=int64)

# %%
np.sort(np.array(pattern['neurons']))
# Out:
# array([ 0,  1,  4,  8,  9, 11, 13, 13, 14, 14], dtype=int32)

# %%
K_sparse[1]
# Out:
# array([ 2, 47, 46, 35, 28,  8, 14, 27, 25, 30], dtype=int64)

# %%
np.sort(np.array(pattern['itemset'])) % D
# Out:
# array([ 0, 45, 44, 33, 26,  6, 12, 25, 23, 28], dtype=int32)

# %%
plt.figure(figsize=(12,6))
plt.scatter(K_sparse[1],K_sparse[0],s=100)
plt.scatter(np.sort(np.array(pattern['itemset'])) % D ,np.sort(np.array(pattern['neurons'])),s=100)
plt.show()

# %%
for i in range(50):
    plt.figure(figsize=(12,6))
    plt.scatter(A_sparse[1],A_sparse[0],s=100)
    plt.scatter(possible_patterns[i][0],possible_patterns[i][1],s=100)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [138], in <cell line: 1>()
#       2 plt.figure(figsize=(12,6))
#       3 plt.scatter(A_sparse[1],A_sparse[0],s=100)
# ----> 4 plt.scatter(possible_patterns[i][0],possible_patterns[i][1],s=100)
#       5 plt.show()
#
# IndexError: list index out of range
